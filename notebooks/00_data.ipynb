# %%
# Improtando Pandas.
import pandas as pd
import matplotlib.pyplot as plt

# %%
# ler excel do repositório remoto.
df = pd.read_csv("https://raw.githubusercontent.com/atlantico-academy/datasets/refs/heads/main/diamonds.csv")

# Exibir as primeiras linhas do DataFrame
print(df)

# Salvar dados da pasta raw.
df.to_csv("../data/raw/data.csv")
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
# Criar dicionário de dados.
data_dictionary = pd.DataFrame([
    {
        "nome_variavel": "Carat",
        "descricao": "Peso do diamante em carats.",
        "tipo": "quantitativa",
        "subtipo": "contínua"
    },
    {
        "nome_variavel": "Cut",
        "descricao": "Qualidade do corte do diamante.",
        "tipo": "qualitativa",
        "subtipo": "ordinal"
    },
    {
        "nome_variavel": "Color",
        "descricao": "Cor do diamante, de D a Z.",
        "tipo": "qualitativa",
        "subtipo": "nominal"
    },
    {
        "nome_variavel": "Clarity",
        "descricao": "Transparência do diamante.",
        "tipo": "qualitativa",
        "subtipo": "ordinal"
    },
    {
        "nome_variavel": "Depth",
        "descricao": "Altura do diamante.",
        "tipo": "quantitativa",
        "subtipo": "contínua"
    },
    {
        "nome_variavel": "Table",
        "descricao": "Superfície plana do diamante.",
        "tipo": "quantitativa",
        "subtipo": "discreta"
    },
    {
        "nome_variavel": "Price",
        "descricao": "Preço do diamante.",
        "tipo": "quantitativa",
        "subtipo": "contínua"
    },
    {
        "nome_variavel": "X",
        "descricao": "Comprimento do diamante no eixo X.",
        "tipo": "quantitativa",
        "subtipo": "contínua"
    },
    {
        "nome_variavel": "Y",
        "descricao": "Largura do diamante no eixo Y.",
        "tipo": "quantitativa",
        "subtipo": "contínua"
    },
    {
        "nome_variavel": "Z",
        "descricao": "Altura do diamante no eixo Z.",
        "tipo": "quantitativa",
        "subtipo": "contínua"
    }
])

# Salvar o dicionário de dados.
data_dictionary.to_csv("../data/external/dictionary.csv", index=False)

# %%
# Visualizando dicionário de dados.
data_dictionary
# Out:
#   nome_variavel                           descricao          tipo   subtipo
# 0         Carat         Peso do diamante em carats.  quantitativa  contínua
# 1           Cut     Qualidade do corte do diamante.   qualitativa   ordinal
# 2         Color          Cor do diamante, de D a Z.   qualitativa   nominal
# 3       Clarity          Transparência do diamante.   qualitativa   ordinal
# 4         Depth                 Altura do diamante.  quantitativa  contínua
# 5         Table       Superfície plana do diamante.  quantitativa  discreta
# 6         Price                  Preço do diamante.  quantitativa  contínua
# 7             X  Comprimento do diamante no eixo X.  quantitativa  contínua
# 8             Y      Largura do diamante no eixo Y.  quantitativa  contínua
# 9             Z       Altura do diamante no eixo Z.  quantitativa  contínua

# %%
# Mudando nome de colunas.
df.rename(columns = {"cut":"corte", "color":"cor", "clarity":"claridade", "depth": "profundidade", "table":"mesa", "price":"preço", "x":"comprimento", "y":"largura", "z":"altura"}, inplace = True)

# Visualização dos primeiros registros.
df.head()
# Out:
#    carat    corte cor claridade  profundidade  mesa  preço  comprimento  \
# 0   0.23    Ideal   E       SI2          61.5  55.0    326         3.95
# 1   0.21  Premium   E       SI1          59.8  61.0    326         3.89
# 2   0.23     Good   E       VS1          56.9  65.0    327         4.05
# 3   0.29  Premium   I       VS2          62.4  58.0    334         4.20
# 4   0.31     Good   J       SI2          63.3  58.0    335         4.34
#
#    largura  altura
# 0     3.98    2.43
# 1     3.84    2.31
# 2     4.07    2.31
# 3     4.23    2.63
# 4     4.35    2.75

# %%
# Resumo estatístico de colunas numéricas.
df.describe()
# Out:
#               carat  profundidade          mesa         preço   comprimento  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#             largura        altura
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# max       58.900000     31.800000

# %% [markdown]
# # Análise exploratória de dados
# - Corte x Preço
# - Cor x Preço
# - Claridade x Preço
#
# Durante a análise de diamantes, foi identificada um correlação positiva entre a qualidade do corte e o preço das pedras. Isso indica que, à medida que a qualidade do corte aumenta, o preço tende a aumentar. No entanto, ao examinar a cor e a claridade dos diamantes, essa correlação não foi observada. Não apresentando padrões claros e indo contra a classificação dos valores de acordo com as cores e as claridade apresentadas, levantando a hipótese de que outros fatores podem influenciar o preço de forma mais complexa. No momento, ainda não se pode inferir essa idéia, e será necessário uma maior análise para provar que existe alguma variável de interferência presente.

# %%
# Calcular a média de preços por tipo de corte
df_avg = df.groupby('corte')['preço'].mean().reset_index()

# Ordenar o DataFrame pela média de preços em ordem decrescente
df_avg = df_avg.sort_values(by='preço', ascending = True)

# Criar o gráfico de barras horizontais
plt.barh(df_avg['corte'], df_avg['preço'], color='skyblue')

# Adicionar título e rótulos
plt.title('Média de Preços por Tipo de Corte')
plt.xlabel('Preço Médio')
plt.ylabel('Corte')

plt.show()

# %%
# Calcular a média de preços por tipo de cor.
df_avg = df.groupby('cor')['preço'].mean().reset_index()

# Ordenar o DataFrame pela média de preços em ordem decrescente
df_avg = df_avg.sort_values(by='preço', ascending = True)

# Criar o gráfico de barras horizontais
plt.barh(df_avg['cor'], df_avg['preço'], color='skyblue')

# Adicionar título e rótulos
plt.title('Média de Preços por Tipo de Cor')
plt.xlabel('Preço Médio')
plt.ylabel('Cor')

plt.show()

# %%
# Calcular a média de preços por tipo de claridade
df_avg = df.groupby('claridade')['preço'].mean().reset_index()

# Ordenar o DataFrame pela média de preços em ordem decrescente
df_avg = df_avg.sort_values(by='preço', ascending = True)

# Criar o gráfico de barras horizontais
plt.barh(df_avg['claridade'], df_avg['preço'], color='skyblue')

# Adicionar título e rótulos
plt.title('Média de Preços por Claridade')
plt.xlabel('Preço Médio')
plt.ylabel('Claridade')

plt.show()

# %% [markdown]
# ## Teste de hipótese
#
# Será criada uma nova coluna no Data Frame, levando em conta as dimensões de comprimento, largura e altura dos diamantes. Além disso, levamos em conta à mesa superior do diamante e a profundidade do diamante, esses paramêtros serão usados para o cálculo do volume dos diamantes, permitindo uma análise mais detalhado e precisa do correlação do tamanho dos diamante com as variáveis de cor e claridade, e utilizando essas correlações para observar uma possível interferência no preço, levantado posteriormente pela hipótese.
